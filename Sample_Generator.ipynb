# %% [markdown]
# # **Importing all files and data (Setup)**

# %%
# Clearing the sample_data directory
# !rm -rf /content/sample_data
# !mkdir /content/sample_data

# Cloning the GitHub repo
# !git clone https://github.com/kaustubhagarwal/DL-Final-Project

# Creating directory to store models
# !mkdir /content/DL-Final-Project/VoiceCloning/saved_models
# !mkdir /content/DL-Final-Project/VoiceCloning/saved_models/default

# Downloading trained model checkpoints stored on Google Drive
# !gdown --id 1e5w7Wi3HpAdWUyFL2XwDghXI73aTusth -O '/content/DL-Final-Project/VoiceCloning/saved_models/default/encoder.pt'
# !gdown --id 1XK9gBsAEkGxtQGDxz5z71fQ2F1x0xX67 -O '/content/DL-Final-Project/VoiceCloning/saved_models/default/synthesizer.pt'
# !gdown --id 1mqSoQEBcd22p0QEDAEDxqsYhqEnfgzxP -O '/content/DL-Final-Project/VoiceCloning/saved_models/default/vocoder.pt'
# !gdown --id 1tI0Ag7EjLSD9M2Yo0b2Kvg9AMrcMeekZ -O '/content/DL-Final-Project/LipSync/checkpoints/wav2lip_gan.pth'
a = !pip install https://raw.githubusercontent.com/kaustubhagarwal/DL-Final-Project/main/Wav2Lip-master/ghc-1.0-py3-none-any.whl
# !gdown --id 1tiUd2u6wLNqaFpOOzEXA7HAGNNaxM9oQ -O "/content/DL-Final-Project/LipSync/face_detection/detection/sfd/s3fd.pth"

# Installing other important libraries
# !pip install -r /content/DL-Final-Project/LipSync/requirements.txt
# !pip install -q youtube-dl
# !pip install ffmpeg-python
# !pip install librosa==0.9.1
# !pip install unidecode
# !pip install webrtcvad
# Out:
# Cloning into 'DL-Final-Project'...
# remote: Enumerating objects: 577, done.
# remote: Counting objects: 100% (308/308), done.
# remote: Compressing objects: 100% (210/210), done.
# remote: Total 577 (delta 155), reused 212 (delta 91), pack-reused 269
# Receiving objects: 100% (577/577), 1.85 MiB | 17.23 MiB/s, done.
# Resolving deltas: 100% (285/285), done.
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1e5w7Wi3HpAdWUyFL2XwDghXI73aTusth
# To: /content/DL-Final-Project/VoiceCloning/saved_models/default/encoder.pt
# 100% 17.1M/17.1M [00:00<00:00, 80.1MB/s]
# ...

# %% [markdown]
# #**Libraries import**

# %%
from IPython.display import HTML, Audio
from google.colab.output import eval_js
from base64 import b64decode
import numpy as np
from scipy.io.wavfile import read as wav_read
import io
import ffmpeg

from IPython.display import clear_output

# %% [markdown]
# #**Taking inputs**

# %% [markdown]
# **In the folder sample_data add the following files**
#
# *   **The audio file should be audio_file.mp3**
# *   **The image should be img_sample.jpg**

# %%
inp = ''
while inp!='y':
  inp = input('Have you stored the files in the right format? Enter y for yes to continue ')
# Out:
# Have you stored the files in the right format? Enter y for yes to continue y

# %%
text_speak = input('What do you want the voice to say? ')
# Out:
# What do you want the voice to say? This is an amazing project

# %% [markdown]
# #**Generating an audio file for the text in the given sample's voice**

# %%
# !python /content/DL-Final-Project/VoiceCloning/demo_cli.py --text "{text_speak}"
# Out:
# Preparing the encoder, the synthesizer and the vocoder...
# Loaded encoder "encoder.pt" trained to step 1564501
# Synthesizer using device: cpu
# Building Wave-RNN
# Trainable Parameters: 4.481M
# Loading model weights at /content/DL-Final-Project/VoiceCloning/saved_models/default/vocoder.pt
# Trainable Parameters: 30.870M
# Loaded synthesizer "synthesizer.pt" trained to step 295000
#
# | Generating 1/1
#
#
# Done.
#
# ...
# Loaded file succesfully
# Created the embedding
#
# | Generating 1/1
#
#
# Done.
#
# Created the mel spectrogram
# Synthesizing the waveform:
# {| ████████████████ 38000/38400 | Batch Size: 4 | Gen Rate: 1.0kHz | }float64
#
# Saved output as /content/audio_output.wav

# %% [markdown]
# #**Generating the final video where the person in the image is speaking**

# %%
# !cd DL-Final-Project/LipSync && python /content/DL-Final-Project/LipSync/inference.py --checkpoint_path checkpoints/wav2lip_gan.pth --face "/content/sample_data/img_sample.jpg" --audio "/content/audio_output.wav"
# Out:
# Using cpu for inference.
# Number of frames available for inference: 1
# /content/DL-Final-Project/LipSync/audio.py:100: FutureWarning: Pass sr=16000, n_fft=800 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.filters.mel(hp.sample_rate, hp.n_fft, n_mels=hp.num_mels,
# (80, 157)
# Length of mel chunks: 46
#   0% 0/1 [00:00<?, ?it/s]
#   0% 0/1 [00:00<?, ?it/s]
# 100% 1/1 [00:03<00:00,  3.00s/it]
# checkpoints/wav2lip_gan.pth
# Load checkpoint from: checkpoints/wav2lip_gan.pth
# Model loaded
# 100% 1/1 [00:12<00:00, 12.73s/it]
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %% [markdown]
# #**Playing the resulting video**

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('/content/result.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f"""
<video width="50%" height="50%" controls>
      <source src="{data_url}" type="video/mp4">
</video>""")
# Out:
# <video width="50%" height="50%" controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
