# %%
# Clearing the sample_data directory
# !rm -rf /content/sample_data
# !mkdir /content/sample_data

# Cloning the GitHub repo
# !git clone https://github.com/kaustubhagarwal/DL-Final-Project

# Creating directory to store models
# !mkdir /content/DL-Final-Project/Real-Time-Voice-Cloning-master/saved_models
# !mkdir /content/DL-Final-Project/Real-Time-Voice-Cloning-master/saved_models/default

# Downloading trained model checkpoints stored on Google Drive
# !gdown --id 1e5w7Wi3HpAdWUyFL2XwDghXI73aTusth -O '/content/DL-Final-Project/Real-Time-Voice-Cloning-master/saved_models/default/encoder.pt'
# !gdown --id 1XK9gBsAEkGxtQGDxz5z71fQ2F1x0xX67 -O '/content/DL-Final-Project/Real-Time-Voice-Cloning-master/saved_models/default/synthesizer.pt'
# !gdown --id 1mqSoQEBcd22p0QEDAEDxqsYhqEnfgzxP -O '/content/DL-Final-Project/Real-Time-Voice-Cloning-master/saved_models/default/vocoder.pt'
# !gdown --id 1tI0Ag7EjLSD9M2Yo0b2Kvg9AMrcMeekZ -O '/content/DL-Final-Project/Wav2Lip-master/checkpoints/wav2lip_gan.pth'
a = !pip install https://raw.githubusercontent.com/kaustubhagarwal/DL-Final-Project/main/Wav2Lip-master/ghc-1.0-py3-none-any.whl
# !gdown --id 1tiUd2u6wLNqaFpOOzEXA7HAGNNaxM9oQ -O "/content/DL-Final-Project/Wav2Lip-master/face_detection/detection/sfd/s3fd.pth"

# Installing other important libraries
# !pip install -r /content/DL-Final-Project/Wav2Lip-master/requirements.txt
# !pip install -q youtube-dl
# !pip install ffmpeg-python
# !pip install librosa==0.9.1
# !pip install unidecode
# !pip install webrtcvad
# Out:
# Cloning into 'DL-Final-Project'...
# remote: Enumerating objects: 278, done.
# remote: Counting objects: 100% (278/278), done.
# remote: Compressing objects: 100% (264/264), done.
# remote: Total 278 (delta 107), reused 58 (delta 3), pack-reused 0
# Receiving objects: 100% (278/278), 276.56 KiB | 1.51 MiB/s, done.
# Resolving deltas: 100% (107/107), done.
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1e5w7Wi3HpAdWUyFL2XwDghXI73aTusth
# To: /content/DL-Final-Project/Real-Time-Voice-Cloning-master/saved_models/default/encoder.pt
# 100% 17.1M/17.1M [00:00<00:00, 43.0MB/s]
# ...

# %%
from IPython.display import HTML, Audio
from google.colab.output import eval_js
from base64 import b64decode
import numpy as np
from scipy.io.wavfile import read as wav_read
import io
import ffmpeg

from IPython.display import clear_output

# %%
text_speak = input('What do you want the voice to say?')
# Out:
# What do you want the voice to say?This team creates some amazing models

# %%
# !python /content/DL-Final-Project/Real-Time-Voice-Cloning-master/demo_cli.py --text "{text_speak}"
# Out:
# Preparing the encoder, the synthesizer and the vocoder...
# Loaded encoder "encoder.pt" trained to step 1564501
# Synthesizer using device: cpu
# Building Wave-RNN
# Trainable Parameters: 4.481M
# Loading model weights at /content/DL-Final-Project/Real-Time-Voice-Cloning-master/saved_models/default/vocoder.pt
# Trainable Parameters: 30.870M
# Loaded synthesizer "synthesizer.pt" trained to step 295000
#
# | Generating 1/1
#
#
# Done.
#
# Loaded file succesfully
# Created the embedding
#
# | Generating 1/1
#
#
# Done.
#
# Created the mel spectrogram
# Synthesizing the waveform:
# {| ████████████████ 47500/48000 | Batch Size: 5 | Gen Rate: 1.3kHz | }float64
#
# Saved output as /content/DL-Final-Project/Real-Time-Voice-Cloning-master/demo_output.wav

# %%
# !cd DL-Final-Project/Wav2Lip-master && python /content/DL-Final-Project/Wav2Lip-master/inference.py --checkpoint_path checkpoints/wav2lip_gan.pth --face "/content/sample_data/elon_musk_royal_society.jpg" --audio "/content/DL-Final-Project/Real-Time-Voice-Cloning-master/demo_output.wav"
# Out:
# Using cpu for inference.
# Number of frames available for inference: 1
# /content/DL-Final-Project/Wav2Lip-master/audio.py:100: FutureWarning: Pass sr=16000, n_fft=800 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.filters.mel(hp.sample_rate, hp.n_fft, n_mels=hp.num_mels,
# (80, 205)
# Length of mel chunks: 61
#   0% 0/1 [00:00<?, ?it/s]
#   0% 0/1 [00:00<?, ?it/s]
# 100% 1/1 [00:19<00:00, 19.21s/it]
# checkpoints/wav2lip_gan.pth
# Load checkpoint from: checkpoints/wav2lip_gan.pth
# Model loaded
# 100% 1/1 [00:33<00:00, 33.97s/it]
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('/content/DL-Final-Project/Wav2Lip-master/result_voice.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f"""
<video width="50%" height="50%" controls>
      <source src="{data_url}" type="video/mp4">
</video>""")
# Out:
# <video width="50%" height="50%" controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
